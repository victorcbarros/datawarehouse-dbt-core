# %%
import pandas as pd

# %%
# URL do CSV na AWS
url1 = 'https://ons-aws-prod-opendata.s3.amazonaws.com/dataset/fator_capacidade_2_di/FATOR_CAPACIDADE-2_2023_01.csv'

# %%
# Carregar o CSV diretamente em um DataFrame
df = pd.read_csv(url,sep=';')

# %%
# Exibir as primeiras linhas do DataFrame
df.shape
# Out:
# (138624, 20)

# %%
df.sample(10)
# Out:
#        id_subsistema        nom_subsistema id_estado           nom_estado  \
# 62211             SE  Sudeste/Centro-Oeste        SP            SAO PAULO
# 101200             N                 Norte        MA             MARANHAO
# 87690              S                   Sul        RS    RIO GRANDE DO SUL
# 83895             NE              Nordeste        PI                PIAUI
# 87377             NE              Nordeste        BA                BAHIA
# 71863             NE              Nordeste        PB              PARAIBA
# 30700             NE              Nordeste        RN  RIO GRANDE DO NORTE
# 122243            NE              Nordeste        RN  RIO GRANDE DO NORTE
# 98735             NE              Nordeste        BA                BAHIA
# 126991            NE              Nordeste        RN  RIO GRANDE DO NORTE
#
#                   nom_pontoconexao nom_localizacao  val_latitudesecoletora  \
# 62211        GETULINA - 138 kV (A)             NaN              -21.893809
# ...
